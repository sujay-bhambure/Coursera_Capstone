# %% [markdown]
# # Business Problem
# ### As a food blogger visiting Toronto city, I want to stay at a hotel such that my travelling distance in minimal to all restraurents in the city

# %% [markdown]
# #

# %% [markdown]
# ### Hotels and Restraurent data for Toronto city extracted using Foursquare API, Hotels are repreented by red markers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Calulate Distance from every hotel to restraurent

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Find Hotel with minimum distance from all restraurents

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Pantages Hotel & Spa is the recommened hotel which has minimum distance from all restraurents and represented by black marker

# %% [markdown]
# ![image.png](attachment:image.png)
